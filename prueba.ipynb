# %%
import src.rag.rag as rag

maquina=rag.rag(False, False, 0.7)

maquina.purgarBasesDatos()
maquina.newBoeDocument("BOE-A-2007-18391")

response, texts = maquina.preguntar("que dice el articulo 4 de la ley 11/2007", True)
print(texts)
print(response)
print("\n")
maquina.newBoeDocument("BOE-A-2015-10565")

response, texts = maquina.preguntar("que dice el articulo 4 de la ley 11/2007", True)
print(texts)
print(response)
# Out:
# Batches: 100%|███████████████████████████████████| 3/3 [00:00<00:00, 101.58it/s]
# Texto añadido con éxito
# ...
# Batches: 100%|███████████████████████████████████| 1/1 [00:00<00:00, 803.97it/s]
# BOE-A-2007-18391: Artículo 4. Libertad personal.. https://www.boe.eshttps://www.boe.es/boe/dias/2007/10/23/pdfs/A42914-42922.pdf
# ley orgánica 11/2007
# Los miembros de la Guardia Civil sólo podrán ser privados de su libertad en los casos previstos por las Leyes y en la forma en que éstas dispongan.
#
# BOE-A-2007-18391: Artículo 6. Libertad de desplazamiento y circulación.. https://www.boe.eshttps://www.boe.es/boe/dias/2007/10/23/pdfs/A42914-42922.pdf
# ley orgánica 11/2007
# ...
